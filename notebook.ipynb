# %%
# Install all libraries you'll need
# !pip install pandas numpy scikit-learn xgboost matplotlib seaborn folium geopy requests

# For Google Earth Engine (optional, but recommended)
# !pip install ee
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ee: filename=ee-0.2-py3-none-any.whl size=3655 sha256=c83a240f5965e895995040cc90b5867e3c836775ef508d488178b1d6af2b6399
#   Stored in directory: /root/.cache/pip/wheels/68/e5/fb/285c24eaa7ce9d3844e311635dea798b3c4c9ceb6c32cd1da4
# Successfully built ee
# ...
